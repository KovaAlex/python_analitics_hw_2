# %%
import pandas as pd

# %% [markdown]
# ## Задание 1.
#
# - Скачать данные по ссылке https://www.kaggle.com/datasets/ionaskel/laptop-prices
# - Считать данные с помощью pandas
# - Вывести на экран первые 5 строк
# - Посмотреть на описание признаков и на их содержание

# %%
df = pd.read_csv('./kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# Скачал csv файл, командой .read_csv() считал данные

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# Вывел первые 5 строк

# %%
df.shape
# Out:
# (21613, 21)

# %% [markdown]
# Посмотрел сколько строк и столбцов

# %% [markdown]
# ## Задание 2.
#
# ![image.png](attachment:image.png)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# Вывел свобную таблицу по типам данных где получил следующую инфу dtypes: float64(5), int64(15), object(1)

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# проверил на отсутствие пропущенных ячеек 2 способами. Пропущенных ячеек - нет :(

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# получил основную статистику по данной таблице:
# 1. count - количество не пропущенных объектов.
# 2. mean - среднее арифметическое по кажой из колонок.
# 3. std - стандартное отклонение.
# 4. min - минимальное значение по колонке.
# 5. 25% - квантиль 25 процентов.
# 6. 50% - квантиль 50 процентов.
# 7. 75% - квантиль 75 процентов.
# 8. max - максимальное значение.

# %%
df.describe(include='object')
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %% [markdown]
# Так как по информации из .info()  у нас в data есть одна строковое значение object, ввыел его из это инфы можем получить следующее:
# 1. count - количество не пропущенных объектов;
# 2. unique - количество уникальных значений;
# 3. top - самое частое значение;
# 4. freq - частота появления самого частого значения.

# %% [markdown]
# ## Задание 3.
#
# 3.1 В каком диапазоне изменяются стоимости недвижимости?
#
# 3.2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам?
#
# 3.3 Как много домов с разными этажами в данных?
#
# 3.4 Насколько хорошие состояния у домов в данных?
#
# 3.5 Найдите года, когда построили первый дом, когда построили последний дом в данных?

# %% [markdown]
# ### 3.1 В каком диапазоне изменяются стоимости недвижимости?

# %%
df['price'].min(), df['price'].max()
# Out:
# (75000.0, 7700000.0)

# %% [markdown]
# стоимость недвижимости по данной таблице варьируется от:
#
# min = 75000.0
#
# max = 7700000.0

# %% [markdown]
# ### 3.2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам?

# %%
(df['sqft_living'].mean()/df['sqft_lot'].mean()*100).round(2)
# Out:
# 13.77

# %% [markdown]
# ### 3.3 Как много домов с разными этажами в данных?

# %%
df['floors'].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %% [markdown]
# ### 3.4 Насколько хорошие состояния у домов в данных?

# %%
df.condition.value_counts().sort_values()
# Out:
# 1       30
# 2      172
# 5     1701
# 4     5679
# 3    14031
# Name: condition, dtype: int64

# %% [markdown]
# Для разнообразия отсортировал данные от меньшего к большему и здесь мы може видеть что плохих домов с оценкой "1" всего 30 штук, а отличных домов с оценкой "5" - 1701. Ниже сделал еще в процентах сколько каких домой по состоянию

# %%
round(df.condition.value_counts(normalize=True).sort_values()*100, 2)
# Out:
# 1     0.14
# 2     0.80
# 5     7.87
# 4    26.28
# 3    64.92
# Name: condition, dtype: float64

# %% [markdown]
# ### 3.5 Найдите года, когда построили первый дом, когда построили последний дом в данных?

# %%
df.yr_built.min()
# Out:
# 1900

# %%
df.yr_built.max()
# Out:
# 2015

# %% [markdown]
# получается что самый первый дом был построен в 1900 году, последний в 2015. Чтобы проверить себя можно отсортровать по дате постройке, что мы и ниже сделаем:

# %%
df.sort_values('yr_built')
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 4697   9126101645  20140610T000000  558000.0         4       2.00
# 2961   1947300115  20140619T000000  464000.0         3       1.00
# 12369  9138100350  20150218T000000  685000.0         4       2.00
# 15016  1703400585  20141215T000000  325000.0         3       2.00
# 5236    844000425  20141223T000000  199999.0         3       1.00
# ...           ...              ...       ...       ...        ...
# 21270  1773100541  20150417T000000  389950.0         3       2.25
# 17098  9126100346  20140617T000000  350000.0         3       2.00
# 7526   9520900210  20141231T000000  614285.0         5       2.75
# 20086  2768100512  20150422T000000  659000.0         2       2.50
# 14489  2770601530  20140826T000000  500000.0         2       2.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 4697          2180      3870     1.0           0     0  ...      7
# ...

# %% [markdown]
# ## Заданиче 4.
#
# Ответьте на несколько вопросов
#
# 4.1 Сколько в среднем стоят дома, у которых 2 спальни?
#
# 4.2 Какая в среднем общая площадь домов, у которых стоимость больше 600 000?
#
# 4.3 Как много домов коснулся ремонт?
#
# 4.4 Насколько в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой grade меньше 4?

# %% [markdown]
# ### 4.1 Сколько в среднем стоят дома, у которых 2 спальни?

# %%
round(df[df['bedrooms'] == 2]['price'].mean(), 2)
# Out:
# 401372.68

# %% [markdown]
# ### 4.2 Какая в среднем общая площадь домов, у которых стоимость больше 600 000?

# %%
df[df.price > 600000]['sqft_lot'].mean()
# Out:
# 20442.524776214832

# %% [markdown]
# ### 4.3 Как много домов коснулся ремонт?

# %%
df.yr_renovated.unique()
# Out:
# array([   0, 1991, 2002, 2010, 1999, 1992, 2013, 1994, 1978, 2005, 2008,
#        2003, 1984, 1954, 2014, 2011, 1974, 1983, 1945, 1990, 1988, 1957,
#        1977, 1981, 1995, 2000, 1998, 1970, 1989, 2004, 1986, 2009, 2007,
#        1987, 1973, 2006, 1985, 2001, 1980, 1971, 1979, 1997, 1950, 1969,
#        1948, 2015, 1968, 2012, 1963, 1951, 1993, 1962, 1996, 1972, 1953,
#        1955, 1982, 1956, 1940, 1976, 1946, 1975, 1958, 1964, 1959, 1960,
#        1967, 1965, 1934, 1944])

# %% [markdown]
# Вывел уникальные значения, чтобы посмотреть все года ремонтов))) зачем сам не знаю xD

# %%
df[df['yr_renovated'] != 0].shape[0]
# Out:
# 914

# %%
df[df.yr_renovated.astype('bool')]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 35     9547205180  20140613T000000   696000.0         3       2.50
# 95     1483300570  20140908T000000   905000.0         4       2.50
# 103    2450000295  20141007T000000  1088000.0         3       2.50
# 115    3626039325  20141121T000000   740500.0         3       3.50
# ...           ...              ...        ...       ...        ...
# 19622  7351200295  20150114T000000  1150000.0         3       1.75
# 20057   126039256  20140904T000000   434900.0         3       2.00
# 20444  4305600360  20150225T000000   500012.0         4       2.50
# 20447  3319500628  20150212T000000   356999.0         3       1.50
# 20962  1278000210  20150311T000000   110000.0         2       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1             2570      7242     2.0           0     0  ...      7
# ...

# %% [markdown]
# Решил 2 способами:
# 1. Задал условие что года ремонта не равны нулю и вывел количество строк - 914 домов ремонтировались.
# 2. Использовал astype, просто в конце строки не стал выводить shape, чтобы наглядно можно было посмотреть что год ремонта не равен 0

# %% [markdown]
# ### 4.4 Насколько в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой grade меньше 4?

# %%
df[df['grade'] > 10]['price'].mean() - df[df['grade'] < 4]['price'].mean()
# Out:
# 1488885.1175298805

# %% [markdown]
# ## Задание 5.
#
# 5.1 Выберите дом клиенту
#
# Клиент хочет дом с видом на набережную, как минимум с тремя ванными и с подвалом. Сколько вариантов есть у клиента?
#
# 5.2 Выберите дом клиенту
#
# Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, в очень хорошем состоянии и год постройки не меньше 1980 года. В какой ценовом диапазоне будут дома?
#
# 5.3 Выберите дом клиенту
#
# Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000. Какая оценка по состоянию у таких домов в среднем?

# %% [markdown]
# ### 5.1 Выберите дом клиенту
#
# Клиент хочет дом с видом на набережную, как минимум с тремя ванными и с подвалом. Сколько вариантов есть у клиента?

# %%
df[(df['waterfront'] == 1) & (df['bathrooms'] >= 3) & (df['sqft_basement'] > 0)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# 457    2122039094  20141126T000000   705000.0         3       3.00
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 1261   7636800041  20140625T000000   995000.0         3       4.50
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1361   1925069082  20150511T000000  2200000.0         5       4.25
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 2864   4114601570  20141118T000000  3600000.0         3       3.25
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 3934   1269200229  20140723T000000  1379900.0         3       3.25
# 5760    623059016  20140717T000000  1100000.0         4       3.25
# 6233   2024069008  20140619T000000  2200000.0         5       4.75
# 6508   4217402115  20150421T000000  3650000.0         6       4.75
# ...

# %% [markdown]
# можно вывести просто количество доступных домов, а так их 41 штука

# %%
df[(df['waterfront'] == 1) & (df['bathrooms'] >= 3) & (df['sqft_basement'] > 0)].shape[0]
# Out:
# 41

# %% [markdown]
# ### 5.2 Выберите дом клиенту
#
# Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, в очень хорошем состоянии и год постройки не меньше 1980 года. В какой ценовом диапазоне будут дома?

# %%
client_choice = df[((df['view'] == 4) | (df['waterfront'] == 1)) & (df['condition'] == 5) & (df['yr_built'] >= 1980)]['price']
client_choice.min(), client_choice.max()
# Out:
# (1295000.0, 3000000.0)

# %% [markdown]
# ### 5.3 Выберите дом клиенту
#
# Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000. Какая оценка по состоянию у таких домов в среднем?

# %%
round(df[(df['sqft_basement'] == 0) & (df['floors'] == 2) & (df['price'] < 150000)]['condition'].mean(), 2)
# Out:
# 2.83
